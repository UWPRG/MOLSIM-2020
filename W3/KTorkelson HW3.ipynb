# %% [markdown]
# ### HW 3: Gaussian
# #### Kaylyn Torkelson

# %% [markdown]
# Geometry Optimization
#
#      Functional/Basis Set       Energy in AU       Energy in kJ/mol    CPU Time
#     i. HF/STO-3G                  -39.727               -104283       3.0 seconds
#     ii. HF/3-21G*                 -39.977               -104939       3.0 seconds
#     iii. HF/6-31G**               -40.202               -105529       2.8 seconds
#     iv. B3LYP/3-21G*              -40.302               -105791       3.9 seconds
#     v. B3LYP/6-31G**              -40.524               -106376       5.3 seconds
#     vi. B3LYP/DGDZVP              -40.523               -106374       4.8 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt

objects = ('HF/STO-3G', 'HF/3-21G*', 'HF/6-31G**', 'B3LYP/3-21G*', 'B3LYP/6-31G**', 'B3LYP/DGDZVP')
y_pos = np.arange(len(objects))
x = [3.0,3.0,2.8,3.9,5.3,4.8]

plt.figure(figsize=(12,8))
plt.bar(y_pos, x, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Choice of Functional/Basis Set')
plt.ylabel('CPU Time in Seconds')
plt.title('Theory Effect on Computation Time')

plt.show()
