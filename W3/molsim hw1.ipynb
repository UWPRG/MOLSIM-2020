# %%
basis_set = ['HF/STO-3G','HF/3-21G*','HF/6-21G**', 'B3LYP/3-21G*','B3LYP/6-21G**', 'B3LYP/DGDZVP']

# %%
basis_set
# Out:
# ['HF/STO-3G',
#  'HF/3-21G*',
#  'HF/6-21G**',
#  'B3LYP/3-21G*',
#  'B3LYP/6-21G**',
#  'B3LYP/DGDZVP']

# %%
time=[5.7, 4.5, 5.3, 3.7, 3.2, 3.8]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 10))
plt.bar(basis_set,time)
# Out:
# <BarContainer object of 6 artists>

# %%
from PIL import Image

# %%
img = Image.open('/Users/nisargjoshi/Desktop/energy.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=450x200 at 0x1047A6CF8>
